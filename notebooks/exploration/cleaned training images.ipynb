# %%
from PIL import Image
import numpy as np

# %%
file = '../../data/clean/train/kam/kam_train_2000.npy'

# %%
array = np.load(file)

# %%
display(Image.fromarray(array), Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7F457EAB2A20>
# 1

# %%
file = '../../data/clean/train/kam/kam_train_1.npy'

# %%
array = np.load(file)

# %%
display(Image.fromarray(array), Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7F457E8450B8>
# 1
