# %%
import geopandas as gpd

# %%
file = 'bc32f1-labels/bc32f1.geojson'
gdf = gpd.read_file(file)

# %%
gdf
# Out:
#     id            changeset problemati   condition             area building  \
# 0    1  2017-08-16T17:49:43       None    Complete     35.783203125      yes
# 1    2  2017-08-16T17:49:43       None    Complete   31.51708984375      yes
# 2    3  2017-08-16T17:49:43       None    Complete   15.62548828125      yes
# 3    4  2017-08-16T17:49:43       None    Complete    33.2822265625      yes
# 4    5  2017-08-16T17:49:43       None    Complete    27.8095703125      yes
# 5    6  2017-08-16T17:49:43       None    Complete    94.8193359375      yes
# 6    7  2017-08-16T17:49:43       None    Complete   44.61474609375      yes
# 7    8  2017-08-16T17:49:43       None    Complete   39.36865234375      yes
# 8    9  2017-08-16T17:49:43       None    Complete   19.14892578125      yes
# 9   10  2017-08-16T17:49:43       None    Complete    80.1552734375      yes
# 10  11  2017-08-16T17:49:43       None    Complete     3.3994140625      yes
# ...

# %%
gdf.plot()

# %%
file2 = 'bc32f1/bc32f1.tif'

# %%
from PIL import Image

# %%
import PIL

# %%
PIL.Image.MAX_IMAGE_PIXELS = 1713427900

# %%
im = Image.open(file2)

# %%
import numpy as np

# %%
x = np.array(im)

# %%
x.shape
# Out:
# (40155, 40180, 4)

# %%
im.show()

# %%
x1 = x[:224, :224, :3]

# %%
x2 = Image.fromarray(x1)

# %%
display(x2, PIL.Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F396F405E80>
# 1

# %%
y1 = x[21000:22000, 22000:23000]

# %%
y2 = Image.fromarray(y1)

# %%
display(y2, PIL.Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000 at 0x7F396F40A048>
# 1
